# %%
import pandas as pd
import pyodbc 
cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=BLUEPANDA;"
                      "Database=ETLCourse;"
                      "Trusted_Connection=yes;")


cursor = cnxn.cursor()
cursor.execute('SELECT * FROM dbo.spy')
counter = 0
for row in cursor:
    if counter < 20:
        print('row = %r' % (row,))
    counter += 1
# Out:
# row = ('2014-03-26', '187.04', '187.34', '184.92', '184.97', '119595000', '184.97')
# row = ('2014-03-25', '186.37', '186.94', '185.27', '186.31', '103852000', '186.31')
# row = ('2014-03-24', '186.84', '187.07', '184.62', '185.43', '121411200', '185.43')
# row = ('2014-03-21', '187.71', '189.02', '186.03', '186.20', '163128000', '186.20')
# row = ('2014-03-20', '186.25', '187.89', '185.92', '187.75', '117241000', '186.93')
# row = ('2014-03-19', '187.68', '187.94', '185.47', '186.66', '176267300', '185.84')
# row = ('2014-03-18', '186.71', '187.91', '186.51', '187.66', '101804600', '186.84')
# row = ('2014-03-17', '185.59', '186.77', '185.51', '186.33', '98359500', '185.51')
# row = ('2014-03-14', '184.85', '185.80', '184.44', '184.66', '153919600', '183.85')
# row = ('2014-03-13', '187.84', '187.99', '184.66', '185.18', '155014300', '184.37')
# row = ('2014-03-12', '186.32', '187.35', '185.90', '187.28', '104824400', '186.46')
# ...
